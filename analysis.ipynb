# %%
import pandas as pd

df = pd.read_csv('df_litecon.csv')

# %%
"""
Perform OLS to see effect of domain and gender
"""
# Out:
# '\nPerform OLS to see effect of domain and gender\n'

# %%
import statsmodels.formula.api as smf

# Citations model
model_cite = smf.ols(
    formula='citation_counts ~ C(gender) + year +  C(domain)',
    data=df
).fit()

print(model_cite.summary())

# Novelty model
model_nov = smf.ols(
    formula='novelty ~ C(gender) + year  + C(domain)',
    data=df
).fit()

print(model_nov.summary())

model_prec = smf.ols(
    formula='precocity ~ C(gender) + year + C(domain)',
    data=df
).fit()

print(model_prec.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        citation_counts   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     606.9
# Date:                Sat, 15 Nov 2025   Prob (F-statistic):               0.00
# Time:                        13:32:19   Log-Likelihood:            -5.4352e+05
# No. Observations:               68549   AIC:                         1.087e+06
# Df Residuals:                   68544   BIC:                         1.087e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept            -5981.8240    264.639    -22.604      0.000   -6500.516   -5463.132
# ...

# %%
import statsmodels.formula.api as smf

# Citations model
model_cite = smf.ols(
    formula='citation_counts ~ C(gender) + year + C(journal) + C(domain)',
    data=df
).fit()

print(model_cite.summary())

# Novelty model
model_nov = smf.ols(
    formula='novelty ~ C(gender) + year + C(journal) + C(domain)',
    data=df
).fit()

print(model_nov.summary())

model_prec = smf.ols(
    formula='precocity ~ C(gender) + year + C(journal) + C(domain)',
    data=df
).fit()

print(model_prec.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        citation_counts   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     177.8
# Date:                Sat, 15 Nov 2025   Prob (F-statistic):               0.00
# Time:                        13:32:23   Log-Likelihood:            -5.4323e+05
# No. Observations:               68549   AIC:                         1.086e+06
# Df Residuals:                   68531   BIC:                         1.087e+06
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as smf

# Citations model
model_cite = smf.ols(
    formula='citation_counts ~ C(gender) * C(domain) + year + C(journal)',
    data=df
).fit()

print(model_cite.summary())

# Novelty model
model_nov = smf.ols(
    formula='novelty ~ C(gender) * C(domain) + year + C(journal)',
    data=df
).fit()

print(model_nov.summary())

model_prec = smf.ols(
    formula='precocity ~ C(gender) * C(domain) + year + C(journal) + C(domain)',
    data=df
).fit()

print(model_prec.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        citation_counts   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     163.9
# Date:                Sat, 15 Nov 2025   Prob (F-statistic):               0.00
# Time:                        19:42:04   Log-Likelihood:            -5.4319e+05
# No. Observations:               68549   AIC:                         1.086e+06
# Df Residuals:                   68529   BIC:                         1.087e+06
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# ...
