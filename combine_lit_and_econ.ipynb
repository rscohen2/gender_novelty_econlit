# %%
"""
Read in the metadata and merge with the novelty data for lit data
"""

data_dir = 'lit_data/precocity'
all_dfs = []

import pandas as pd
import os
import re
# Load metadata
df_meta = pd.read_csv('lit_data/lit_metadata/LitMetadataWithS2.tsv', sep='\t')

# Load all paper data files
print("Reading data files...")
for file in os.listdir(data_dir):
    if file.endswith('.tsv'):
        match = re.search(r'(\d{4})', os.path.basename(file))
        year = match.group(1) if match else 'unknown'
        # print(f"Processing {csv} (year: {year})")
        path = os.path.join(data_dir, file)
        df = pd.read_csv(path, sep='\t')
        df['paperId'] = df['docid']
        df['decade'] = year
        merged = df_meta.merge(df, on='paperId', how='left')
        all_dfs.append(merged)


gender_meta = pd.read_csv('lit_data/author_genders_lit.csv')
#read in the gender data we have already

gender_meta = gender_meta[gender_meta['gender'].isin(['male', 'female'])]

df_all = pd.concat(all_dfs, ignore_index=True)


"deduplicate the data by selecting one set of parameters ted recommended"

#filter for only male/female gender and also for the single set of novelty results (time chunks etc)

#chunks_used
    #use 0.25 (top 25% most novel chunks)
df_all = df_all.loc[df_all['chunks_used'] == 0.25]

#time_radius
    #use 20
df_all = df_all.loc[df_all['time_radius'] == 20]


#filtered
    #use trainauthquote
df_all = df_all.loc[df_all['filtered'] == 'trainauthquote']



#fraction_compared
    #10 percent most similar vs all articles... use all articles aka 1.0

df_all = df_all.loc[df_all['fraction_compared'] == 1.0]
# Out:
# Reading data files...

# %%
""" explode out author list"""

"""
Split up author names in lists with semicolons or commas.
Clean/lowercase all author names.
"""

def split_authors(authors_str):
    # Replace commas with semicolons, then split on semicolons
    if not isinstance(authors_str, str):
        return []
    authors = re.split(r'[;,]', authors_str)  # split on semicolon or comma
    authors = [a.strip() for a in authors if a.strip()]  # remove empty strings
    return authors


def clean_author_name2(name):
    if isinstance(name, str):
        name = name.strip()
        name = name.lower()
        name = name.replace('[', '').replace(']', '')
        name = name.replace('"', '').replace("'", '')
        return name.strip()
    return name


df_all['authors'] = df_all['authors'].apply(split_authors)
df_all = df_all.explode('authors')

# %%
import ast

def flatten_author(author):
    # If it's already a list, leave it
    if isinstance(author, list):
        return author[0] if len(author) == 1 else ", ".join(author)

    # If it's a string that looks like a list, convert it
    if isinstance(author, str):
        try:
            parsed = ast.literal_eval(author)
            if isinstance(parsed, list):
                return parsed[0] if len(parsed) == 1 else ", ".join(parsed)
        except Exception:
            # fallback: just return the original string
            return author

    return author

df_all['authors'] = df_all['authors'].apply(flatten_author)

# %%
#num_chunks
    #I don't think this one needed to be filtered?


    #apply gender dict
gender_dict = pd.Series(gender_meta['gender'].values, index=gender_meta['author']).to_dict()
df_all['gender'] = df_all['authors'].map(gender_dict).fillna('unknown')


df_all_lit = df_all

# %%
df_all_lit.to_csv('df_all_lit.csv')

# %% [markdown]
# Now we pre-process all the econ data here

# %%
"""
Read in the metadata and merge with the novelty data for econ data
"""

data_dir = 'econ_data/precocity'
all_dfs = []
# Load metadata
df_meta = pd.read_csv('econ_data/econ_metadata/all-econ-S2metaWyearcol.tsv', sep='\t')
# Load all paper data files
print("Reading data files...")
for file in os.listdir(data_dir):
    if file.endswith('.tsv'):
        match = re.search(r'(\d{4})', os.path.basename(file))
        year = match.group(1) if match else 'unknown'
        # print(f"Processing {csv} (year: {year})")
        path = os.path.join(data_dir, file)
        df = pd.read_csv(path, sep='\t')
        df['paperId'] = df['docid']
        df['decade'] = year
        merged = df_meta.merge(df, on='paperId', how='left')
        all_dfs.append(merged)

gender_meta = pd.read_csv('econ_data/author_gender_econ.csv')

gender_meta = gender_meta[gender_meta['gender'].isin(['male', 'female'])]

#read in the gender data we have already

df_all = pd.concat(all_dfs, ignore_index=True)



"deduplicate the data by selecting one set of parameters ted recommended"

#filter for only male/female gender and also for the single set of novelty results (time chunks etc)

#chunks_used
    #use 0.25 (top 25% most novel chunks)
df_all = df_all.loc[df_all['chunks_used'] == 0.25]

#time_radius
    #use 20
df_all = df_all.loc[df_all['time_radius'] == 20]


#filtered
    #use trainauthquote
df_all = df_all.loc[df_all['filtered'] == 'trainauthquote']



#fraction_compared
    #10 percent most similar vs all articles... use all articles aka 1.0

df_all = df_all.loc[df_all['fraction_compared'] == 1.0]
# Out:
# Reading data files...

# %%
""" explode out author list"""

"""
Split up author names in lists with semicolons or commas.
Clean/lowercase all author names.
"""

def split_authors(authors_str):
    # Replace commas with semicolons, then split on semicolons
    if not isinstance(authors_str, str):
        return []
    authors = re.split(r'[;,]', authors_str)  # split on semicolon or comma
    authors = [a.strip() for a in authors if a.strip()]  # remove empty strings
    return authors


def clean_author_name2(name):
    if isinstance(name, str):
        name = name.strip()
        name = name.lower()
        name = name.replace('[', '').replace(']', '')
        name = name.replace('"', '').replace("'", '')
        return name.strip()
    return name


df_all['creator'] = df_all['creator'].apply(split_authors)
df_all = df_all.explode('creator')

# %%
import ast

def flatten_author(author):
    # If it's already a list, leave it
    if isinstance(author, list):
        return author[0] if len(author) == 1 else ", ".join(author)

    # If it's a string that looks like a list, convert it
    if isinstance(author, str):
        try:
            parsed = ast.literal_eval(author)
            if isinstance(parsed, list):
                return parsed[0] if len(parsed) == 1 else ", ".join(parsed)
        except Exception:
            # fallback: just return the original string
            return author

    return author

df_all['creator'] = df_all['creator'].apply(flatten_author)

# %%
#num_chunks
    #I don't think this one needed to be filtered?


    #apply gender dict
gender_dict = pd.Series(gender_meta['gender'].values, index=gender_meta['author']).to_dict()
df_all['gender'] = df_all['creator'].map(gender_dict).fillna('unknown')


df_all_econ = df_all

# %%
df_all_lit.head()
# Out:
#                  doi                        journal  year  \
# 17    10.2307/461288                           PMLA  1967
# 68   10.2307/3723455     The Modern Language Review  1969
# 174  10.2307/3721313     The Modern Language Review  1963
# 339   10.2307/460722                           PMLA  1963
# 404   10.2307/512220  The Review of English Studies  1967
#
#                         authors                                    title  \
# 17        Jean-Jacques Demorest                Pascal et le déséquilibre
# 68             Patricia Thomson                           Review Article
# 174           Margaret McHaffie                           Review Article
# 339  Lillian Herlands Hornstein  King Robert of Sicily: A New Manuscript
# 404         William H. Matchett             Donne's 'Peece of Chronicle'
#
#     language  wordcount                     doctype  citation_counts  \
# 17   ['fre']       4999  article | research-article                0
# 68   ['eng']       1243       article | book-review                8
# 174  ['eng']        600       article | book-review                0
# 339  ['eng']       3991  article | research-article                0
# 404  ['eng']        920  article | research-article                0
#
#                                               S2titles  ... num_chunks  \
# 17                           Pascal et le déséquilibre  ...        7.0
# 68   The English Petrarchans : a critical bibliogra...  ...        2.0
# 174  Jeremias Gotthelf : eine Einführung in seine W...  ...        1.0
# 339            King Robert of Sicily: A New Manuscript  ...        7.0
# 404                       DONNE'S ’PEECE OF CHRONICLE‘  ...        1.0
#
#     fraction_compared        filtered time_radius chunks_used  precocity  \
# 17                1.0  trainauthquote        20.0        0.25  -0.013390
# 68                1.0  trainauthquote        20.0        0.25   0.284837
# 174               1.0  trainauthquote        20.0        0.25   0.235353
# 339               1.0  trainauthquote        20.0        0.25   0.112459
# 404               1.0  trainauthquote        20.0        0.25   0.280793
#
#       novelty transience decade   gender
# 17   8.627299   8.640689   1960     male
# 68   5.996719   5.711883   1960   female
# 174  6.185017   5.949665   1960  unknown
# 339  6.578631   6.466172   1960   female
# 404  5.364418   5.083625   1960  unknown
#
# [5 rows x 30 columns]

# %%
df_all_econ.head()
# Out:
#      index                                   id  \
# 16       3  http://www.jstor.org/stable/1808956
# 74      32  http://www.jstor.org/stable/1884001
# 136     78  http://www.jstor.org/stable/1811027
# 136     78  http://www.jstor.org/stable/1811027
# 184     78  http://www.jstor.org/stable/1811027
#
#                                                  title  \
# 16   Tariffs, Intermediate Goods, and Domestic Prot...
# 74   Revealed Preference and the Demand Theorem in ...
# 136     The Differential Effects of Tight Money: Reply
# 136     The Differential Effects of Tight Money: Reply
# 184     The Differential Effects of Tight Money: Reply
#
#                                isPartOf  publicationYear              doi  \
# 16         The American Economic Review             1969  10.2307/1808956
# 74   The Quarterly Journal of Economics             1969  10.2307/1884001
# 136        The American Economic Review             1963  10.2307/1811027
# 136        The American Economic Review             1963  10.2307/1811027
# 184        The American Economic Review             1963  10.2307/1811027
#
#      docType        docSubType provider  collection  ... num_chunks  \
# 16   article  research-article    jstor         NaN  ...       15.0
# 74   article  research-article    jstor         NaN  ...        4.0
# 136  article  research-article    jstor         NaN  ...        3.0
# 136  article  research-article    jstor         NaN  ...        3.0
# 184  article  research-article    jstor         NaN  ...        3.0
#
#     fraction_compared        filtered time_radius chunks_used precocity  \
# 16                1.0  trainauthquote        20.0        0.25  0.038633
# 74                1.0  trainauthquote        20.0        0.25 -0.008110
# 136               1.0  trainauthquote        20.0        0.25  0.026900
# 136               1.0  trainauthquote        20.0        0.25  0.026900
# 184               1.0  trainauthquote        20.0        0.25  0.018749
#
#       novelty transience decade   gender
# 16   0.005717  -0.032916   1960  unknown
# 74  -0.004197   0.003913   1960  unknown
# 136 -0.015106  -0.042006   1960  unknown
# 136 -0.015106  -0.042006   1960  unknown
# 184 -0.020036  -0.038785   1960  unknown
#
# [5 rows x 46 columns]

# %%
print(df_all_econ.columns)
# Out:
# Index(['index', 'id', 'title', 'isPartOf', 'publicationYear', 'doi', 'docType',
#        'docSubType', 'provider', 'collection', 'datePublished', 'issueNumber',
#        'volumeNumber', 'url', 'creator', 'publisher', 'language', 'pageStart',
#        'pageEnd', 'placeOfPublication', 'keyphrase', 'wordCount', 'pageCount',
#        'file', 'paperId', 'citationCount', 'foundTitle', 'foundYear',
#        'foundAuthors', 'citations', 'paperSource', 'doiMatch', 'searchMatch',
#        'year', 'docid', 'date', 'num_chunks', 'fraction_compared', 'filtered',
#        'time_radius', 'chunks_used', 'precocity', 'novelty', 'transience',
#        'decade', 'gender'],
#       dtype='object')

# %%
df_all_econ['creator'].head()
# Out:
# 16      Roy J. Ruffin
# 74     Tapas Majumdar
# 136        G. L. Bach
# 136    C. J. Huizenga
# 184        G. L. Bach
# Name: creator, dtype: object

# %%
df_all_econ.rename(columns={'creator': 'authors'}, inplace=True)

# %%
df_all_econ.rename(columns={'isPartOf': 'journal'}, inplace=True)

# %%
df_all_econ.rename(columns={'citationCount': 'citation_counts'}, inplace=True)

# %%
# df_all_econ.rename(columns={'publicationYear': 'year'}, inplace=True)

# %%
df_all_econ_filtered = df_all_econ[['authors','journal','citation_counts','precocity','novelty','gender','year']].copy()

# %%
df_all_lit_filtered = df_all_lit[['authors','journal','citation_counts','precocity','novelty','gender','year']].copy()

# %%
df_all_econ_filtered.loc[:, 'domain'] = 'econ'

# %%
df_all_lit_filtered.loc[:, 'domain'] = 'lit'

# %%
df_all_econ_filtered.index.is_unique   # should be True
# Out:
# False

# %%
df_all_lit_filtered.index.is_unique    # should be True
# Out:
# False

# %%
df_all_econ_filtered.columns[df_all_econ_filtered.columns.duplicated()]
# Out:
# Index([], dtype='object')

# %%
df_all_econ_filtered.reset_index(drop=True, inplace=True)
df_all_lit_filtered.reset_index(drop=True, inplace=True)

df_concat_litecon = pd.concat(
    [df_all_econ_filtered, df_all_lit_filtered],
    ignore_index=True
)

# %%
df_all_econ_filtered.index[df_all_econ_filtered.index.duplicated()]
# Out:
# Index([], dtype='int64')

# %%
df_concat_litecon.to_csv('df_litecon.csv')

# %%
df_concat_litecon.head()
# Out:
#           authors                             journal  citation_counts  \
# 0   Roy J. Ruffin        The American Economic Review               44
# 1  Tapas Majumdar  The Quarterly Journal of Economics                6
# 2      G. L. Bach        The American Economic Review                1
# 3  C. J. Huizenga        The American Economic Review                1
# 4      G. L. Bach        The American Economic Review                1
#
#    precocity   novelty   gender  year domain
# 0   0.038633  0.005717  unknown  1969   econ
# 1  -0.008110 -0.004197  unknown  1969   econ
# 2   0.026900 -0.015106  unknown  1963   econ
# 3   0.026900 -0.015106  unknown  1963   econ
# 4   0.018749 -0.020036  unknown  1963   econ

# %%
df_concat_litecon.tail()
# Out:
#                   authors                        journal  citation_counts  \
# 68544      Carlos Fuentes     The Modern Language Review                0
# 68545          Hugh White  The Review of English Studies                0
# 68546    John T. Matthews                            ELH                2
# 68547     Hinrich Siefken     The Modern Language Review                0
# 68548  Barrie Ruth Straus                            ELH               18
#
#        precocity   novelty   gender  year domain
# 68544   0.180122  5.312028     male  1989    lit
# 68545   0.112379  5.490325     male  1987    lit
# 68546   0.396130  5.409131     male  1980    lit
# 68547   0.165402  5.226582  unknown  1982    lit
# 68548   0.404571  5.552968  unknown  1988    lit
